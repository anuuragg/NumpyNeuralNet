# %%
import pandas as pd
import matplotlib.pyplot as plt
from main import *

df = pd.DataFrame(epoch_loss)
df_plot = df.plot(kind="line", grid=True, figsize=(10,6), color='orange', linewidth=2, marker='o', markersize=6)

plt.title('Epoch Loss over Time', fontsize=16)
plt.xlabel('Epoch', fontsize=14)
plt.ylabel('Loss', fontsize=14)

plt.legend(['Loss'], loc='upper right')
plt.grid(True, linestyle='--', alpha=0.7)

plt.show()
